# %% [markdown]
# <a href="https://colab.research.google.com/github/jgraving/deepposekit/blob/master/examples/step1_create_annotation_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepPoseKit Step 1 - Create an annotation set
#
# This is step 1 of the example notebooks for using DeepPoseKit. This notebook shows you how to load and sample images from a video, define a keypoint skeleton, and save the data to a file for labelling with keypoints.
#
#
# **NOTE**: If you run into problems, you can help us improve DeepPoseKit by [opening an issue](https://github.com/jgraving/deepposekit/issues/new) or [submitting a pull request](https://help.github.com/en/articles/creating-a-pull-request-from-a-fork)

# %% [markdown]
# If you haven't already installed DeepPoseKit you can run the next cell

# %%
import sys
# !{sys.executable} -m pip install -U deepposekit

# %%
import numpy as np
import cv2
import h5py
import matplotlib.pyplot as plt
from deepposekit.io import VideoReader, DataGenerator, initialize_dataset
from deepposekit.annotate import KMeansSampler
import tqdm
import glob
import pandas as pd

from os.path import expanduser

try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

HOME = '.'

# %% [markdown]
# Use the next cell to download the example data into your home directory

# %%
# !git clone https://github.com/jgraving/deepposekit-data {HOME + '/deepposekit-data'}

# %% [markdown]
# # A note on image resolutions
#
# Currently DeepPoseKit only supports image resolutions that can be repeatedly divided by 2. For example, all of these values are valid image resolutions for either height or width:

# %%
exp = np.arange(1,12)
exp = 2**exp

print(1*exp)
print(3*exp)
print(5*exp)
print(7*exp)
print(11*exp)
# Out:
# [   2    4    8   16   32   64  128  256  512 1024 2048]
# [   6   12   24   48   96  192  384  768 1536 3072 6144]
# [   10    20    40    80   160   320   640  1280  2560  5120 10240]
# [   14    28    56   112   224   448   896  1792  3584  7168 14336]
# [   22    44    88   176   352   704  1408  2816  5632 11264 22528]

# %% [markdown]
# Images that do not match these resolutions must be manually resized, cropped, or padded. We are working to add automated image size adjustments.

# %% [markdown]
# # Open a video
# The `VideoReader` class allows you to load in single video frames or batches of frames from nearly any video format.

# %%
videos = glob.glob(HOME + '/deepposekit-data/datasets/locust/*.avi')
videos
# Out:
# ['./deepposekit-data/datasets/locust/video.avi',
#  './deepposekit-data/datasets/locust/video2.avi']

# %%
reader = VideoReader(HOME + '/deepposekit-data/datasets/locust/outpy.avi', gray=True)
frame = reader[0] # read a frame
reader.close()
frame.shape
# Out:
# (1, 896, 896, 1)

# %%
plt.figure(figsize=(5,5))
plt.imshow(frame[0,...,0])
plt.show()

# %% [markdown]
# # Sample video frames
# This loads batches of 100 frames from the video, and then randomly samples frames from the batches to hold them in memory. You can use any method for sampling frames.

# %%
reader = VideoReader(HOME + '/deepposekit-data/datasets/locust/outpy.avi', batch_size=100, gray=True)

randomly_sampled_frames = []
for idx in tqdm.tqdm(range(len(reader)-1)):
    batch = reader[idx]
    random_sample = batch[np.random.choice(batch.shape[0], 10, replace=False)]
    randomly_sampled_frames.append(random_sample)
reader.close()

randomly_sampled_frames = np.concatenate(randomly_sampled_frames)
randomly_sampled_frames.shape
# Out:
# 100%|██████████| 26/26 [00:14<00:00,  1.82it/s]
# (260, 896, 896, 1)

# %% [markdown]
# # Apply k-means to reduce correlation
#
# This applies the k-means algorithm to the images using `KMeansSampler` to even out sampling across the distribution of images and reduce correlation within the annotation set.

# %%
kmeans = KMeansSampler(n_clusters=4, max_iter=1000, n_init=10, batch_size=100, verbose=True)
kmeans.fit(randomly_sampled_frames)
# Out:
# Init 1/10 with method: k-means++
# Inertia for init 1/10: 7332413689.783134
# Init 2/10 with method: k-means++
# Inertia for init 2/10: 6574725989.734463
# Init 3/10 with method: k-means++
# Inertia for init 3/10: 6638092648.355774
# Init 4/10 with method: k-means++
# Inertia for init 4/10: 6634324679.664047
# Init 5/10 with method: k-means++
# Inertia for init 5/10: 6787236560.102119
# Init 6/10 with method: k-means++
# Inertia for init 6/10: 6429580079.898361
# Init 7/10 with method: k-means++
# Inertia for init 7/10: 6600518727.464352
# Init 8/10 with method: k-means++
# Inertia for init 8/10: 7301865590.234406
# Init 9/10 with method: k-means++
# Inertia for init 9/10: 6584202611.417824
# Init 10/10 with method: k-means++
# Inertia for init 10/10: 6511423097.856720
# Minibatch iteration 1/3000: mean batch inertia: 26810622.710810, ewa inertia: 26810622.710810
# Minibatch iteration 2/3000: mean batch inertia: 25961310.366028, ewa inertia: 26159808.653506
# Minibatch iteration 3/3000: mean batch inertia: 26172555.839586, ewa inertia: 26169576.612188
# Minibatch iteration 4/3000: mean batch inertia: 24823559.668342, ewa inertia: 25138146.003877
# Minibatch iteration 5/3000: mean batch inertia: 26188603.755632, ewa inertia: 25943094.472655
# Minibatch iteration 6/3000: mean batch inertia: 26058022.421406, ewa inertia: 26031161.866334
# Minibatch iteration 7/3000: mean batch inertia: 25894668.149637, ewa inertia: 25926568.979976
# Minibatch iteration 8/3000: mean batch inertia: 25004536.740286, ewa inertia: 25220030.865271
# Minibatch iteration 9/3000: mean batch inertia: 26815763.966002, ewa inertia: 26442814.850506
# Minibatch iteration 10/3000: mean batch inertia: 26857065.384170, ewa inertia: 26760248.209635
# Minibatch iteration 11/3000: mean batch inertia: 25486962.614445, ewa inertia: 25784550.435543
# Minibatch iteration 12/3000: mean batch inertia: 26987651.618172, ewa inertia: 26706467.050584
# Minibatch iteration 13/3000: mean batch inertia: 24959122.052628, ewa inertia: 25367505.366326
# Minibatch iteration 14/3000: mean batch inertia: 26325934.879100, ewa inertia: 26101934.111747
# Converged (lack of improvement in inertia) at iteration 14/3000
# Computing label assignment and total inertia
# KMeansSampler(batch_size=100, compute_labels=True, init='k-means++',
#               init_size=None, max_iter=1000, max_no_improvement=10,
#               n_clusters=4, n_init=10, random_state=None,
#               reassignment_ratio=0.01, tol=0.0, verbose=True)

# %%
kmeans.plot_centers(n_rows=2)
plt.show()

# %%
kmeans_sampled_frames, kmeans_cluster_labels = kmeans.sample_data(randomly_sampled_frames, n_samples_per_label=4)
kmeans_sampled_frames.shape
# Out:
# Computing label assignment and total inertia
# Computing label assignment and total inertia
# (16, 896, 896, 1)

# %% [markdown]
# # Define a keypoints skeleton file
# You must create a .xlsx or .csv file with keypoint names, parent relationships, and swapping relationships for bilaterally symmetric parts (only relevant if using flipping augmentations). If you leave out the `parent` and `swap` columns, then these will simply not be used for annotating data and training the model.
#
# See example skeleton.csv files for more details

# %%
skeleton = pd.read_csv(HOME + '/deepposekit-data/datasets/locust/skeleton.csv')
skeleton
# Out:
#          name     parent       swap
# 0        head        NaN        NaN
# 1        neck       head        NaN
# 2     anttipL        NaN    anttipR
# 3    antbaseL    anttipL   antbaseR
# 4   forelegL1        NaN  forelegR1
# 5   forelegL2  forelegL1  forelegR2
# 6    midlegL1        NaN   midlegR1
# 7    midlegL2   midlegL1   midlegR2
# 8     anttipR        NaN    anttipL
# 9    antbaseR    anttipR   antbaseL
# 10  forelegR1        NaN  forelegL1
# 11  forelegR2  forelegR1  forelegL2
# 12   midlegR1        NaN   midlegL1
# 13   midlegR2   midlegR1   midlegL2

# %% [markdown]
# # Initialize a new data set for annotations
#
# You can use any method for sampling images to create a numpy array with the shape (n_images, height, width, channels) and then initialize an annotation set. Check the doc string for more details:

# %%
initialize_dataset?

# %%
initialize_dataset(
    images=kmeans_sampled_frames,
    datapath=HOME + '/deepposekit-data/datasets/locust/example_annotation_set.h5',
    skeleton=HOME + '/deepposekit-data/datasets/locust/skeleton.csv',
    # overwrite=True # This overwrites the existing datapath
)

# %% [markdown]
# # Create a data generator
# This creates a `DataGenerator` for loading annotated data. Indexing the generator returns an image-keypoints pair, which you can then visualize. Right now all the keypoints are set to zero, because they haven't been annotated.
#
# You can also look at the doc string for more explanation:

# %%
DataGenerator?

# %%
data_generator = DataGenerator(HOME + '/deepposekit-data/datasets/locust/example_annotation_set.h5', mode="full")

image, keypoints = data_generator[0]

plt.figure(figsize=(5,5))
image = image[0] if image.shape[-1] is 3 else image[0, ..., 0]
cmap = None if image.shape[-1] is 3 else 'gray'
plt.imshow(image, cmap=cmap, interpolation='none')
for idx, jdx in enumerate(data_generator.graph):
    if jdx > -1:
        plt.plot(
            [keypoints[0, idx, 0], keypoints[0, jdx, 0]],
            [keypoints[0, idx, 1], keypoints[0, jdx, 1]],
            'r-'
        )
plt.scatter(keypoints[0, :, 0], keypoints[0, :, 1], c=np.arange(data_generator.keypoints_shape[0]), s=50, cmap=plt.cm.hsv, zorder=3)

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/deepposekit/io/DataGenerator.py:81: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   self.annotated = np.all(h5file["annotated"].value, axis=1)
